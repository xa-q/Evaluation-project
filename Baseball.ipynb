# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('Basketball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
sns.heatmap(df.isnull().sum().to_frame())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
df.plot(kind='box',subplots=True, layout=(8,4),figsize=(10,20))
# Out:
# W         AxesSubplot(0.125,0.799681;0.168478x0.0803191)
# R      AxesSubplot(0.327174,0.799681;0.168478x0.0803191)
# AB     AxesSubplot(0.529348,0.799681;0.168478x0.0803191)
# H      AxesSubplot(0.731522,0.799681;0.168478x0.0803191)
# 2B        AxesSubplot(0.125,0.703298;0.168478x0.0803191)
# 3B     AxesSubplot(0.327174,0.703298;0.168478x0.0803191)
# HR     AxesSubplot(0.529348,0.703298;0.168478x0.0803191)
# BB     AxesSubplot(0.731522,0.703298;0.168478x0.0803191)
# SO        AxesSubplot(0.125,0.606915;0.168478x0.0803191)
# SB     AxesSubplot(0.327174,0.606915;0.168478x0.0803191)
# RA     AxesSubplot(0.529348,0.606915;0.168478x0.0803191)
# ER     AxesSubplot(0.731522,0.606915;0.168478x0.0803191)
# ERA       AxesSubplot(0.125,0.510532;0.168478x0.0803191)
# CG     AxesSubplot(0.327174,0.510532;0.168478x0.0803191)
# SHO    AxesSubplot(0.529348,0.510532;0.168478x0.0803191)
# SV     AxesSubplot(0.731522,0.510532;0.168478x0.0803191)
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
dff=df[(z<3).all(axis=1)]

# %%
dff.shape
# Out:
# (29, 17)

# %%
dff['E']=np.log(dff['E'])
dff['E'].skew()
# Out:
# 0.5833075389348484

# %%
dff['SHO']=np.log(dff['SHO'])
dff['SHO'].skew()
# Out:
# -0.7261238398670306

# %%
dff['SV']=np.log(dff['SV'])
dff['SV'].skew()
# Out:
# 0.09675174266622452

# %%
dff['H']=np.log(dff['H'])
dff['H'].skew()
# Out:
# 0.7384225982580486

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
dff.corr
# Out:
# <bound method DataFrame.corr of       W    R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  724  5575  7.311218  300  42  139  383   973  104  641  601  3.73
# 1    83  696  5467  7.207119  277  44  156  439  1264   70  700  653  4.07
# 2    81  669  5439  7.240650  303  29  141  533  1157   86  640  584  3.67
# 3    76  622  5533  7.230563  260  27  136  404  1231   68  701  643  3.98
# 4    74  689  5605  7.323171  289  49  151  455  1259   83  803  746  4.64
# 6    87  764  5567  7.242082  272  19  212  554  1227   63  698  652  4.03
# 7    81  713  5485  7.222566  246  20  217  418  1331   44  693  646  4.05
# 8    80  644  5485  7.232010  278  32  167  436  1310   87  642  604  3.74
# 9    78  748  5640  7.309881  294  33  161  478  1148   71  753  694  4.31
# 10   88  751  5511  7.257708  279  32  172  503  1233  101  733  680  4.24
# 11   86  729  5459  7.217443  278  26  230  486  1392  121  618  572  3.57
# ...

# %%
import statsmodels.api as ss
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc(d):
    vif=pd.DataFrame()
    vif['Variable']=d.columns
    vif['vif factor']=[variance_inflation_factor(d.values,i) for i in range(d.shape[1])]
    return (vif)

# %%
x=df1.iloc[:,1:]
y=df1['W']

# %%
calc(x)
# Out:
#    Variable    vif factor
# 0         R   1684.071804
# 1        AB   4386.435411
# 2         H   4542.383497
# 3        2B    874.293076
# 4        3B     35.695117
# 5        HR    267.423009
# 6        BB    260.583556
# 7        SO    399.764153
# 8        SB     28.928494
# 9        RA  17975.314054
# 10       ER  50845.193939
# 11      ERA  23146.472801
# 12       CG      6.207366
# 13      SHO     30.820866
# 14       SV    117.346095
# 15        E     92.554014

# %%
x.drop('ER',axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x1 = sc.fit_transform(x)
x1
# Out:
# array([[ 0.95939835,  0.83008422,  1.73830631,  1.55653766,  1.01084549,
#         -0.76586314, -1.53635899, -2.72762331,  0.9059529 , -0.66451353,
#         -0.51138828, -0.50148589, -0.81326172,  1.64315663, -0.47109143],
#        [ 0.33114717, -0.70283074, -0.93869788,  0.20117132,  1.20891656,
#         -0.18138864, -0.49502051,  0.12189552, -0.58531515,  0.15463823,
#          0.23895226, -0.50148589,  0.15929869,  0.21100645, -0.61489829],
#        [-0.27466646, -1.10025314, -0.10665604,  1.73332457, -0.2766165 ,
#         -0.69710144,  1.25294051, -0.9258657 ,  0.11645805, -0.67839746,
#         -0.64380131,  2.85461197, -0.32698152, -0.70036184, -1.1182223 ],
#        [-1.32923093,  0.23395062, -0.35988616, -0.8006212 , -0.47468758,
#         -0.8690057 , -1.14585706, -0.20124579, -0.6730368 ,  0.16852216,
#          0.04033271,  1.36301292, -0.57012162, -0.83055731,  0.46365315],
#        [ 0.17408438,  1.25589393,  2.0638879 ,  0.90831897,  1.70409425,
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
maxr2=0
mse=0
best_score=0
rs=0
lr=LinearRegression()
for i in range(5000):
 
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    score=lr.score(x_train,y_train)
    predl=lr.predict(x_test)
    r2=r2_score(y_test,predl)
    ms=mean_squared_error(y_test,predl)
    if maxr2<r2:
        maxr2=r2
        mse=ms
        best_score=score
        rs=i
print(f"Random state: {rs}\n score  {best_score} \n where r2 score is {maxr2}\n and mean squared error is {mse}  ")
# Out:
# Random state: 1398
#  score  0.9309316265780521
#  where r2 score is 0.9827793196688265
#  and mean squared error is 2.614194944718427

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1398)

# %%
import joblib
joblib.dump(r2,'Baseball.obj')
# Out:
# ['Baseball.obj']
